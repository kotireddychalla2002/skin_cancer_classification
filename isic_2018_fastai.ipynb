# %%
from fastai.vision.all import *
import pandas as pd

# %%
train_folder = r"D:\4-1\ProjectWork\datasets\isic2018\combined_train_valid"

# %%
files = get_image_files(train_folder)

# %%
len(files)
# Out:
# 10208

# %%
files[0]
# Out:
# Path('D:/4-1/ProjectWork/datasets/isic2018/combined_train_valid/ISIC_0024306.jpg')

# %%
train_labels = r"C:\Users\chall\Documents\Project\practice\test\train_valid.csv"

# %%
df = pd.read_csv(train_labels)

# %%
df.head()
# Out:
#               image  label
# 0  ISIC_0024306.jpg      1
# 1  ISIC_0024307.jpg      1
# 2  ISIC_0024308.jpg      1
# 3  ISIC_0024309.jpg      1
# 4  ISIC_0024310.jpg      0

# %%
dls = ImageDataLoaders.from_df(df, train_folder)

# %%
dls.show_batch()
